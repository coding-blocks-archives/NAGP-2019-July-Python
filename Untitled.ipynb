# %% [markdown]
# ## this is a heading

# %% [markdown]
# #### smaller

# %% [markdown]
# * item 1
# * item 2

# %%
a = 456

# %%
# # a
# a
a
# Out:
# 456

# %%
type(a)
# Out:
# int

# %%
b = a**a

# %%
b**10
# Out:
# ...

# %% [markdown]
# ## Arithmetic
#
# ```
#
#
# +
# -
# *
# /
#
# //    -> int div
# **    -> pow
#
#
# ```

# %%
1 // 2
# Out:
# 0

# %%
if True :
    print("Hello")
    
print("i am outside")
# Out:
# Hello
# i am outside

# %%
True and True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
happy = True

# %%
not happy
# Out:
# False

# %% [markdown]
# ## conditional
#
# ```
# >
# <
# >=
# <=
# ==
#
# ```

# %%
a = 44
b = 44

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a = 8

# %%
a += 1

# %%
if a < 10 and b < 50:
    print(a, b)
# Out:
# 9 44

# %%
print("I", "am", "happy", sep="$", end="")
print("I", "am", "happy", sep="$")
# Out:
# I$am$happyI$am$happy

# %%
print?

# %%
y = int(input())
# Out:
# 2000

# %%
if (y % 4) == 0:
    print("leap")
else:
    print("not leap")
# Out:
# leap

# %%
type(y)
# Out:
# int

# %%
float("45678976543")
# Out:
# 45678976543.0

# %%
a = 4678
b = 78

# %%
if a > 5000:
    print("hi")
elif a < 5000:
    print("hiiii")
# Out:
# hiiii

# %%
count = 10

# %%
while count > 0:
    print("Welcome to Nagarro")
    count-=1
# Out:
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro
# Welcome to Nagarro

# %%
list = [56, 77]

# %%
list
# Out:
# [56, 77]
